# %% [markdown]
# <a href="https://colab.research.google.com/github/Mcps40/Dunder/blob/main/data_Cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from  PIL import Image

# %%
# Se abre el archivo en un dataFrame
sourse = pd.read_csv("/content/Mineria_Datos/datos.csv")

# %%
# Se realiza copia de los datos en otro daraFrame para no modificar el archivo original
data = sourse

# %%
# Se agrega un logo del instituto
path="/content/Mineria_Datos/img/logoAIEP.jpg"
display(Image.open(path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x169>

# %% [markdown]
# # Cancer de Mama

# %% [markdown]
# ### Integrantes
#
#
#
#
# *   Manuel López
# *   Marianela Parada
# *   Marco Uribe

# %% [markdown]
# #CRISP-DM 1:  Conocer el negocio

# %% [markdown]
# hablar del negocio con mucha información

# %% [markdown]
# #CRISP-DM 2: Conocer los datos

# %% [markdown]
# radius_mean : Representa **el promedio del radio de los núcleos celulares**, mide la distancia media desde el centro del núcleo hasta su borde. (Los tumores Malignos tienen núcleos más grandes y de forma irregular)

# %%
# De esta forma se muestran los primeros y últimos 5 registros por defecto.
# además, se muestra cuantos registros y columnas tiene el archivo csv.
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# Para mostrar los 5 primeros registros por defecto.
# Si se necesita ver más datos, solo debe agregar un numero entero entre los ().
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# con esta funcion se muestra los 5 últimos registros por defecto
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
#muestra cuantas columnas y registris existen
data.shape
# Out:
# (569, 33)

# %%
# Para visualizar todas las Columnas del dataset
data.columns.values.tolist()
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  'Unnamed: 32']

# %%
# Para visualizar los tipos de datos que tiene cada columna
data.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
# Para revisar los valores unicos de la comlumna diagnosis
# M = Maligno
# B = Benigno
data["diagnosis"].unique().tolist()
# Out:
# ['M', 'B']

# %%
# aqui se realiza el conteo de cada valor unico de la columa diagnosis
diagnosis_counts = data["diagnosis"].value_counts()

# Se muestra el resultado del conteo anterior
display(diagnosis_counts)

# Con esta función se muestra el total de registros
print("\nNúmero total de registros en la columna de diagnosis:")
len(data)
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64
# Número total de registros en la columna de diagnosis:
# 569

# %%
# En este gráfico muestra la cantidad que tiene cada valor
plt.hist(data.diagnosis)
plt.show()

# %% [markdown]
# este gráfico muestra la cantidad ?????=??

# %%
# grafico para ver el porcentaje que tiene cada valor de la columa diagnosis
diagnosis_counts = data['diagnosis'].value_counts()


plt.figure(figsize=(2, 2))
plt.pie(diagnosis_counts, labels=diagnosis_counts.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Distribución de diagnóstico (Benigno vs Maligno)')
plt.show()

# %% [markdown]
# Este gráfico muestra la cantidad de resultados Malignos y Benignos.

# %%
# describe cada columa númerica y entrega el detalle
data.describe()
# para describir una columa en particular se puede usar:
# data["comuna:numerica"].describe()
#para ver un resultado x
# data["columna_numerica"].min()  para ver la minima, se puede la media o cualquier otra.
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Revisamos si nuestra dataframe tiene valores nulos
#data.isnull().sum()

#********************************************************************
#otra opcion de ver si contiene datos nulos
#print("Valores nulos en el data set: " + str(pd.isnull(data).values.ravel().sum()))
#*****************************************************************

# Para ver en mayor detalle de datos nulos, revisamos todas las columnas
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# muestra los valores que tiene la columa diagnosis
data["diagnosis"]
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
#muestra los valores de la columa pero solo 1 vaz
data["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
#para que de en valor numerico cuantos tendo
len(data.diagnosis.unique())
# Out:
# 2

# %%
#muestra por lumna cuantos registros existen
data["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
#grafico scatter
data.plot(kind="scatter", x="radius_mean", y="texture_mean", color="red")
# Out:
# <Axes: xlabel='radius_mean', ylabel='texture_mean'>

# %%
data = pd.read_csv("/content/data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data["texture_mean"].describe()
# Out:
# count    569.000000
# mean      19.289649
# std        4.301036
# min        9.710000
# 25%       16.170000
# 50%       18.840000
# 75%       21.800000
# max       39.280000
# Name: texture_mean, dtype: float64

# %%
data["texture_mean"].mean()
# Out:
# np.float64(19.289648506151142)

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))

plt.subplot(2, 2, 1)
sns.scatterplot(x="radius_mean", y="texture_mean", hue="diagnosis", data=data)
plt.xlabel("Radio Promedio")
plt.ylabel("Textura Promedio")
plt.title("Radio Promedio vs Textura Promedio")

plt.subplot(2, 2, 2)
sns.scatterplot(x="perimeter_mean", y="area_mean", hue="diagnosis", data=data)
plt.xlabel("Perímetro Promedio")
plt.ylabel("Área Promedio")
plt.title("Perímetro Promedio vs Área Promedio")

plt.subplot(2, 2, 3)
sns.scatterplot(x="smoothness_mean", y="compactness_mean", hue="diagnosis", data=data)
plt.xlabel("Suavidad Promedio")
plt.ylabel("Compacidad Promedio")
plt.title("Suavidad Promedio vs Compacidad Promedio")

plt.subplot(2, 2, 4)
sns.scatterplot(x="concavity_mean", y="concave points_mean", hue="diagnosis", data=data)
plt.xlabel("Concavidad Promedio")
plt.ylabel("Puntos Cóncavos Promedio")
plt.title("Concavidad Promedio vs Puntos Cóncavos Promedio")

plt.tight_layout()
plt.show()

# %%
data['diagnosis_encoded'] = data['diagnosis'].apply(lambda x: 1 if x == 'M' else 0)

# Muestra las primeras filas con la nueva columna
display(data[['diagnosis', 'diagnosis_encoded']].head(20))
# Out:
#    diagnosis  diagnosis_encoded
# 0          M                  1
# 1          M                  1
# 2          M                  1
# 3          M                  1
# 4          M                  1
# 5          M                  1
# 6          M                  1
# 7          M                  1
# 8          M                  1
# 9          M                  1
# 10         M                  1
# 11         M                  1
# 12         M                  1
# 13         M                  1
# 14         M                  1
# 15         M                  1
# 16         M                  1
# 17         M                  1
# 18         M                  1
# 19         B                  0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
ax = sns.countplot(x='diagnosis', data=data)
plt.title('Conteo de Diagnósticos')
plt.xlabel('Diagnóstico')
plt.ylabel('Cantidad')

# Calculate percentages
total = len(data)
for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.1f}%'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='bottom')

plt.show()

# %%
display(data.head(20))
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M        17.99         10.38          122.80     1001.0
# 1     842517         M        20.57         17.77          132.90     1326.0
# 2   84300903         M        19.69         21.25          130.00     1203.0
# 3   84348301         M        11.42         20.38           77.58      386.1
# 4   84358402         M        20.29         14.34          135.10     1297.0
# 5     843786         M        12.45         15.70           82.57      477.1
# 6     844359         M        18.25         19.98          119.60     1040.0
# 7   84458202         M        13.71         20.83           90.20      577.9
# 8     844981         M        13.00         21.82           87.50      519.8
# 9   84501001         M        12.46         24.04           83.97      475.9
# 10    845636         M        16.02         23.24          102.70      797.8
# ...

# %%
path="/content/Mineria_Datos/img/mama.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=474x474>

# %%
path1 = "/content/Mineria_Datos/img/logoAIEP.jpg"
img1 = Image.open(path1)

path2 = "/content/Mineria_Datos/img/mama.png"
img2 = Image.open(path2)


fig, axes = plt.subplots(1, 2, figsize=(17, 5))


axes[0].imshow(img1)
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].axis('off')

plt.tight_layout()
plt.show()
